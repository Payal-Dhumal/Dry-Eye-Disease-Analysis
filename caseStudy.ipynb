# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore') # if there are any warning due to version mismatch, it will be ignored

# %%
IMDB_df = pd.read_csv('Dry_Eye_Dataset.csv')
IMDB_df
# Out:
#       Gender  Age  Sleep duration  Sleep quality  Stress level Blood pressure  \
# 0          F   24             9.5              2             1         137/89
# 1          M   39             9.6              2             3         108/64
# 2          F   45             5.4              1             5         134/81
# 3          F   45             5.4              4             5         110/90
# 4          F   42             5.7              3             2          99/67
# ...      ...  ...             ...            ...           ...            ...
# 19995      M   26             9.4              2             3         132/64
# 19996      F   39             7.3              3             4         101/75
# 19997      F   20             8.0              5             3         124/63
# 19998      M   38             4.5              3             3         136/70
# 19999      M   37             5.0              5             3          96/90
#
# ...

# %%
IMDB_df.shape
# Out:
# (20000, 26)

# %%
IMDB_df.head()
# Out:
#   Gender  Age  Sleep duration  Sleep quality  Stress level Blood pressure  \
# 0      F   24             9.5              2             1         137/89
# 1      M   39             9.6              2             3         108/64
# 2      F   45             5.4              1             5         134/81
# 3      F   45             5.4              4             5         110/90
# 4      F   42             5.7              3             2          99/67
#
#    Heart rate  Daily steps  Physical activity  Height  ...  Smoking  \
# 0          67         3000                 31     161  ...        N
# 1          60        12000                 74     164  ...        N
# 2          95        12000                 93     179  ...        N
# 3          78        19000                 32     160  ...        N
# 4          72         4000                173     179  ...        N
#
#   Medical issue Ongoing medication Smart device before bed  \
# ...

# %%
IMDB_df.columns
# Out:
# Index(['Gender', 'Age', 'Sleep duration', 'Sleep quality', 'Stress level',
#        'Blood pressure', 'Heart rate', 'Daily steps', 'Physical activity',
#        'Height', 'Weight', 'Sleep disorder', 'Wake up during night',
#        'Feel sleepy during day', 'Caffeine consumption', 'Alcohol consumption',
#        'Smoking', 'Medical issue', 'Ongoing medication',
#        'Smart device before bed', 'Average screen time', 'Blue-light filter',
#        'Discomfort Eye-strain', 'Redness in eye',
#        'Itchiness/Irritation in eye', 'Dry Eye Disease'],
#       dtype='object')

# %%
IMDB_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 26 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Gender                       20000 non-null  object
#  1   Age                          20000 non-null  int64
#  2   Sleep duration               20000 non-null  float64
#  3   Sleep quality                20000 non-null  int64
#  4   Stress level                 20000 non-null  int64
#  5   Blood pressure               20000 non-null  object
#  6   Heart rate                   20000 non-null  int64
#  7   Daily steps                  20000 non-null  int64
#  8   Physical activity            20000 non-null  int64
#  9   Height                       20000 non-null  int64
#  10  Weight                       20000 non-null  int64
#  11  Sleep disorder               20000 non-null  object
#  12  Wake up during night         20000 non-null  object
# ...

# %%
IMDB_df.describe()
# Out:
#                 Age  Sleep duration  Sleep quality  Stress level  \
# count  20000.000000    20000.000000   20000.000000  20000.000000
# mean      31.422800        6.998245       2.997250      2.993750
# std        8.103717        1.731723       1.412283      1.407235
# min       18.000000        4.000000       1.000000      1.000000
# 25%       24.000000        5.500000       2.000000      2.000000
# 50%       31.000000        7.000000       3.000000      3.000000
# 75%       39.000000        8.500000       4.000000      4.000000
# max       45.000000       10.000000       5.000000      5.000000
#
#          Heart rate   Daily steps  Physical activity        Height  \
# count  20000.000000  20000.000000       20000.000000  20000.000000
# mean      79.912200  10536.900000          90.069750    174.865900
# std       11.808279   5752.729186          52.317283     14.719903
# min       60.000000   1000.000000           0.000000    150.000000
# ...

# %%
IMDB_df.describe(include = 'object')
# Out:
#        Gender Blood pressure Sleep disorder Wake up during night  \
# count   20000          20000          20000                20000
# unique      2           1581              2                    2
# top         M         109/73              N                    N
# freq    10028             27          10069                10000
#
#        Feel sleepy during day Caffeine consumption Alcohol consumption  \
# count                   20000                20000               20000
# unique                      2                    2                   2
# top                         N                    Y                   Y
# freq                    10178                10089               10009
#
#        Smoking Medical issue Ongoing medication Smart device before bed  \
# count    20000         20000              20000                   20000
# unique       2             2                  2                       2
# ...

# %%
IMDB_df.Age==20
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 19995    False
# 19996    False
# 19997     True
# 19998    False
# 19999    False
# Name: Age, Length: 20000, dtype: bool

# %%
IMDB_df = IMDB_df.drop_duplicates()

# %%
Age_data = IMDB_df.loc[IMDB_df.Age == 20]  
Age_data
# Out:
#       Gender  Age  Sleep duration  Sleep quality  Stress level Blood pressure  \
# 53         M   20             5.0              4             4         113/70
# 60         M   20             9.1              2             2         131/72
# 105        F   20             8.3              2             4         115/87
# 133        M   20             5.1              3             4          98/86
# 158        M   20             6.2              4             3         129/83
# ...      ...  ...             ...            ...           ...            ...
# 19931      M   20             9.9              5             3         113/77
# 19934      F   20             4.6              2             3         119/77
# 19939      M   20             5.8              2             5         133/72
# 19970      F   20             6.3              4             3         134/83
# 19997      F   20             8.0              5             3         124/63
#
# ...

# %%
duplicateRows = IMDB_df[IMDB_df.duplicated()]

# %%
duplicate_Age = IMDB_df[IMDB_df.duplicated('Age')]
duplicate_Age
# Out:
#       Gender  Age  Sleep duration  Sleep quality  Stress level Blood pressure  \
# 3          F   45             5.4              4             5         110/90
# 5          F   42             5.8              3             1         117/85
# 9          M   33             7.7              4             5         140/88
# 11         M   26             8.9              2             4         115/70
# 12         M   42             6.5              1             3         138/66
# ...      ...  ...             ...            ...           ...            ...
# 19995      M   26             9.4              2             3         132/64
# 19996      F   39             7.3              3             4         101/75
# 19997      F   20             8.0              5             3         124/63
# 19998      M   38             4.5              3             3         136/70
# 19999      M   37             5.0              5             3          96/90
#
# ...

# %%
duplicate_Age.loc[duplicate_Age['Age'] == 20]
# Out:
#       Gender  Age  Sleep duration  Sleep quality  Stress level Blood pressure  \
# 60         M   20             9.1              2             2         131/72
# 105        F   20             8.3              2             4         115/87
# 133        M   20             5.1              3             4          98/86
# 158        M   20             6.2              4             3         129/83
# 165        F   20             4.3              2             3         109/90
# ...      ...  ...             ...            ...           ...            ...
# 19931      M   20             9.9              5             3         113/77
# 19934      F   20             4.6              2             3         119/77
# 19939      M   20             5.8              2             5         133/72
# 19970      F   20             6.3              4             3         134/83
# 19997      F   20             8.0              5             3         124/63
#
# ...

# %%
IMDB_df.isna().any()
# Out:
# Gender                         False
# Age                            False
# Sleep duration                 False
# Sleep quality                  False
# Stress level                   False
# Blood pressure                 False
# Heart rate                     False
# Daily steps                    False
# Physical activity              False
# Height                         False
# Weight                         False
# Sleep disorder                 False
# Wake up during night           False
# Feel sleepy during day         False
# Caffeine consumption           False
# Alcohol consumption            False
# Smoking                        False
# Medical issue                  False
# Ongoing medication             False
# Smart device before bed        False
# Average screen time            False
# Blue-light filter              False
# Discomfort Eye-strain          False
# Redness in eye                 False
# Itchiness/Irritation in eye    False
# ...

# %%
IMDB_df.shape
# Out:
# (20000, 26)

# %%
for i in range(0, IMDB_df.shape[0]):
    IMDB_df['Age'][i] = IMDB_df['Age'][i].replace(',', '')

IMDB_df['Age']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[66], line 2
#       1 for i in range(0, IMDB_df.shape[0]):
# ----> 2     IMDB_df['Age'][i] = IMDB_df['Age'][i].replace(',', '')
#       4 IMDB_df['Age']
#
# AttributeError: 'numpy.int64' object has no attribute 'replace'

# %%
IMDB_df['Age'] = IMDB_df['Age'].astype(str).str.replace(',', '', regex=True).astype(int)

# %%
IMDB_df['Age'] = pd.to_numeric(IMDB_df['Age'], errors='coerce', downcast="integer")
IMDB_df['Sleep duration'] = pd.to_numeric(IMDB_df['Sleep duration'], errors='coerce', downcast="integer")
IMDB_df['Heart rate'] = pd.to_numeric(IMDB_df['Heart rate'], errors='coerce', downcast="integer")

# %%
IMDB_df.isnull().sum()
# Out:
# Gender                         0
# Age                            0
# Sleep duration                 0
# Sleep quality                  0
# Stress level                   0
# Blood pressure                 0
# Heart rate                     0
# Daily steps                    0
# Physical activity              0
# Height                         0
# Weight                         0
# Sleep disorder                 0
# Wake up during night           0
# Feel sleepy during day         0
# Caffeine consumption           0
# Alcohol consumption            0
# Smoking                        0
# Medical issue                  0
# Ongoing medication             0
# Smart device before bed        0
# Average screen time            0
# Blue-light filter              0
# Discomfort Eye-strain          0
# Redness in eye                 0
# Itchiness/Irritation in eye    0
# Dry Eye Disease                0
# dtype: int64

# %%
IMDB_df.isna().sum()
# Out:
# Gender                         0
# Age                            0
# Sleep duration                 0
# Sleep quality                  0
# Stress level                   0
# Blood pressure                 0
# Heart rate                     0
# Daily steps                    0
# Physical activity              0
# Height                         0
# Weight                         0
# Sleep disorder                 0
# Wake up during night           0
# Feel sleepy during day         0
# Caffeine consumption           0
# Alcohol consumption            0
# Smoking                        0
# Medical issue                  0
# Ongoing medication             0
# Smart device before bed        0
# Average screen time            0
# Blue-light filter              0
# Discomfort Eye-strain          0
# Redness in eye                 0
# Itchiness/Irritation in eye    0
# Dry Eye Disease                0
# dtype: int64

# %%
IMDB_df.describe()
# Out:
#                 Age  Sleep duration  Sleep quality  Stress level  \
# count  20000.000000    20000.000000   20000.000000  20000.000000
# mean      31.422800        6.998245       2.997250      2.993750
# std        8.103717        1.731723       1.412283      1.407235
# min       18.000000        4.000000       1.000000      1.000000
# 25%       24.000000        5.500000       2.000000      2.000000
# 50%       31.000000        7.000000       3.000000      3.000000
# 75%       39.000000        8.500000       4.000000      4.000000
# max       45.000000       10.000000       5.000000      5.000000
#
#          Heart rate   Daily steps  Physical activity        Height  \
# count  20000.000000  20000.000000       20000.000000  20000.000000
# mean      79.912200  10536.900000          90.069750    174.865900
# std       11.808279   5752.729186          52.317283     14.719903
# min       60.000000   1000.000000           0.000000    150.000000
# ...

# %%
IMDB_df.describe(include = 'object')
# Out:
#        Gender Blood pressure Sleep disorder Wake up during night  \
# count   20000          20000          20000                20000
# unique      2           1581              2                    2
# top         M         109/73              N                    N
# freq    10028             27          10069                10000
#
#        Feel sleepy during day Caffeine consumption Alcohol consumption  \
# count                   20000                20000               20000
# unique                      2                    2                   2
# top                         N                    Y                   Y
# freq                    10178                10089               10009
#
#        Smoking Medical issue Ongoing medication Smart device before bed  \
# count    20000         20000              20000                   20000
# unique       2             2                  2                       2
# ...

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set_style('darkgrid')  # Set Seaborn style to darkgrid
matplotlib.rcParams['font.size'] = 14  # Set font size for plots
matplotlib.rcParams['figure.figsize'] = (9, 5)  # Set default figure size
matplotlib.rcParams['figure.facecolor'] = '#00000000'  # Set figure background color

# %%
plt.figure(figsize=(20,5))
sns.set(style='dark')
sns.countplot(x=IMDB_df['Age'].sort_values(ascending=False))
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.set(style='dark')
sns.histplot(data=IMDB_df, x='Age', color='indigo', binwidth=1)
plt.show()

# %%
plt.figure(figsize=(16, 6))
plot = sns.countplot(x='Dry Eye Disease', data=IMDB_df)
plt.xticks(rotation=90)
plt.show()

# %%
PG13_Certificate = IMDB_df.loc[IMDB_df['Age'] == 13]
PG13_Certificate
# Out:
# Empty DataFrame
# Columns: [Gender, Age, Sleep duration, Sleep quality, Stress level, Blood pressure, Heart rate, Daily steps, Physical activity, Height, Weight, Sleep disorder, Wake up during night, Feel sleepy during day, Caffeine consumption, Alcohol consumption, Smoking, Medical issue, Ongoing medication, Smart device before bed, Average screen time, Blue-light filter, Discomfort Eye-strain, Redness in eye, Itchiness/Irritation in eye, Dry Eye Disease]
# Index: []
#
# [0 rows x 26 columns]

# %%
plt.figure(figsize=(20, 6))
plot = sns.histplot(PG13_Certificate['Age'], color='r', bins=50, kde=True)
plt.show()

# %%
print(PG13_Certificate.shape)  # Check if rows exist
print(PG13_Certificate.head())  # Display sample rows
# Out:
# (0, 26)
# Empty DataFrame
# Columns: [Gender, Age, Sleep duration, Sleep quality, Stress level, Blood pressure, Heart rate, Daily steps, Physical activity, Height, Weight, Sleep disorder, Wake up during night, Feel sleepy during day, Caffeine consumption, Alcohol consumption, Smoking, Medical issue, Ongoing medication, Smart device before bed, Average screen time, Blue-light filter, Discomfort Eye-strain, Redness in eye, Itchiness/Irritation in eye, Dry Eye Disease]
# Index: []
#
# [0 rows x 26 columns]

# %%
PG13_Certificate = IMDB_df.loc[IMDB_df['Age'] == 13]  # Ensure correct condition

# %%
print(IMDB_df.columns)
# Out:
# Index(['Gender', 'Age', 'Sleep duration', 'Sleep quality', 'Stress level',
#        'Blood pressure', 'Heart rate', 'Daily steps', 'Physical activity',
#        'Height', 'Weight', 'Sleep disorder', 'Wake up during night',
#        'Feel sleepy during day', 'Caffeine consumption', 'Alcohol consumption',
#        'Smoking', 'Medical issue', 'Ongoing medication',
#        'Smart device before bed', 'Average screen time', 'Blue-light filter',
#        'Discomfort Eye-strain', 'Redness in eye',
#        'Itchiness/Irritation in eye', 'Dry Eye Disease'],
#       dtype='object')

# %%
plt.figure(figsize=(20, 6))
plot = sns.histplot(IMDB_df['Age'], color='r', bins=50, kde=True)  # Using 'Age' from your dataset
plt.show()

# %%
plt.figure(figsize=(20, 6))
sns.scatterplot(x=IMDB_df.Age, y=IMDB_df['Daily steps'])  # Replace 'Rate' and 'Votes' with relevant numerical columns
plt.show()

# %%
# Select only numerical columns
numerical_cols = IMDB_df.select_dtypes(include=['number'])

# Calculate the correlation matrix
correlations = numerical_cols.corr()

# Plot the heatmap
f, ax = plt.subplots(figsize=(9, 7))
sns.heatmap(correlations, annot=True, cmap="YlGnBu", linewidths=.5)
plt.show()

# %%
print(IMDB_df.columns)
# Out:
# Index(['Gender', 'Age', 'Sleep duration', 'Sleep quality', 'Stress level',
#        'Blood pressure', 'Heart rate', 'Daily steps', 'Physical activity',
#        'Height', 'Weight', 'Sleep disorder', 'Wake up during night',
#        'Feel sleepy during day', 'Caffeine consumption', 'Alcohol consumption',
#        'Smoking', 'Medical issue', 'Ongoing medication',
#        'Smart device before bed', 'Average screen time', 'Blue-light filter',
#        'Discomfort Eye-strain', 'Redness in eye',
#        'Itchiness/Irritation in eye', 'Dry Eye Disease'],
#       dtype='object')

# %%
IMDB_df.columns = IMDB_df.columns.str.strip().str.lower()  # Convert to lowercase & remove spaces
print(IMDB_df.columns)  # Check again
# Out:
# Index(['gender', 'age', 'sleep duration', 'sleep quality', 'stress level',
#        'blood pressure', 'heart rate', 'daily steps', 'physical activity',
#        'height', 'weight', 'sleep disorder', 'wake up during night',
#        'feel sleepy during day', 'caffeine consumption', 'alcohol consumption',
#        'smoking', 'medical issue', 'ongoing medication',
#        'smart device before bed', 'average screen time', 'blue-light filter',
#        'discomfort eye-strain', 'redness in eye',
#        'itchiness/irritation in eye', 'dry eye disease'],
#       dtype='object')

# %%
print(IMDB_df.columns)
# Out:
# Index(['gender', 'age', 'sleep duration', 'sleep quality', 'stress level',
#        'blood pressure', 'heart rate', 'daily steps', 'physical activity',
#        'height', 'weight', 'sleep disorder', 'wake up during night',
#        'feel sleepy during day', 'caffeine consumption', 'alcohol consumption',
#        'smoking', 'medical issue', 'ongoing medication',
#        'smart device before bed', 'average screen time', 'blue-light filter',
#        'discomfort eye-strain', 'redness in eye',
#        'itchiness/irritation in eye', 'dry eye disease'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.heatmap(IMDB_df.isnull(), cmap="viridis", cbar=False)
plt.title("Missing Values Heatmap")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.lineplot(x='Age', y='Average_Screen_Time', data=df, marker='o', color='green')
plt.title('Average Screen Time by Age')
plt.xlabel('Age')
plt.ylabel('Average Screen Time (hours)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[108], line 2
#       1 plt.figure(figsize=(8, 5))
# ----> 2 sns.lineplot(x='Age', y='Average_Screen_Time', data=df, marker='o', color='green')
#       3 plt.title('Average Screen Time by Age')
#       4 plt.xlabel('Age')
#
# NameError: name 'df' is not defined
